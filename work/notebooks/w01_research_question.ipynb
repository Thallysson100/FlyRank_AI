# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Thallysson100/FlyRank_AI/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I am choosing the **Refresh / Content Opportunity Scoring** lane with the question: *Which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring?* I chose this lane because it directly supports a weekly prioritization decision, it maps well to a ranking task (top pages first), and the starter dataset already contains strong decision signals (visibility, trend direction, freshness, engagement) that can be turned into a practical review queue.

# %%
#Code only

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# This work improves the decision of **which pages enter next week's review queue first**. The actor is a content/SEO editor who chooses actions page by page (refresh, expand, protect, prune, or monitor). A wrong recommendation has two costs: false positives waste limited editor hours on low-impact pages, and false negatives delay high-impact fixes, extending avoidable traffic loss. The output is decision-support ranking, not automation.

# %%
#Code only

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Three numbers support this lane: (1) the dataset has **30,000 pages** to triage, too many for unprioritized manual review; (2) **54.2%** of pages are in a **down** trend (`trend_direction == "down"`), so decline risk is common; and (3) among high-visibility pages (top 25% by impressions, threshold **3,615** impressions/90d), **56.2%** are also in a down trend. That combination suggests a real opportunity to rank limited review effort toward pages with both impact and risk.

# %%
from pathlib import Path
import pandas as pd

candidates = [
    Path("data/raw/content_refresh_anonymized.csv"),
    Path("../data/raw/content_refresh_anonymized.csv"),
    Path("../../data/raw/content_refresh_anonymized.csv"),
]
data_path = next((p for p in candidates if p.exists()), None)
if data_path is None:
    raise FileNotFoundError("Could not find data/raw/content_refresh_anonymized.csv from this notebook location")

df = pd.read_csv(data_path)


total_pages = len(df)
down_share = (df["trend_direction"] == "down").mean()
impr_q75 = df["impressions_90d"].quantile(0.75)
high_visibility = df[df["impressions_90d"] >= impr_q75]
down_share_high_visibility = (high_visibility["trend_direction"] == "down").mean()

print(f"Total pages: {total_pages:,}")
print(f"Share with down trend: {down_share:.1%}")
print(f"Top-quartile impressions threshold (90d): {impr_q75:,.2f}")
print(f"Down-trend share within top-impression quartile: {down_share_high_visibility:.1%}")
# Out:
# Total pages: 30,000
# Share with down trend: 54.2%
# Top-quartile impressions threshold (90d): 3,615.25
# Down-trend share within top-impression quartile: 56.2%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# I can claim observed and measured patterns in this anonymized dataset, plus directional and decision-support recommendations about which pages to review first. I cannot claim causal proof (for example, that a refresh *caused* later recovery) and I cannot claim to predict or reverse-engineer Google's algorithm. Any model or score will be framed as a prioritization aid for human review under uncertainty.

# %%
#Code only

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
